# %%
import pandas as pd # for csv
import numpy as np # for mathematics
from sklearn import linear_model # for ML models
import matplotlib.pyplot as plt # for visualization

# %%
df = pd.read_csv("income_dataset.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.null()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6676\1811596779.py in ?()
# ----> 1 df.null()
#
# ~\Desktop\myenv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'null'

# %%
df.isnull()
# Out:
#      year  per capita income (US$)
# 0   False                    False
# 1   False                    False
# 2   False                    False
# 3   False                    False
# 4   False                    False
# 5   False                     True
# 6   False                    False
# 7   False                    False
# 8   False                    False
# 9   False                    False
# 10  False                    False
# 11  False                    False
# 12  False                    False
# 13  False                    False
# 14  False                    False
# 15  False                    False
# 16  False                    False
# 17  False                    False
# 18  False                    False
# 19  False                    False
# 20  False                    False
# 21  False                     True
# 22  False                    False
# 23  False                    False
# 24  False                    False
# 25  False                    False
# ...

# %%
df.isnull().count()
# Out:
# year                       47
# per capita income (US$)    47
# dtype: int64

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    2
# dtype: int64

# %%
df['per capita income (US$)'].fillna(df['per capita income (US$)'].mean())
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5     19244.048888
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    19244.048888
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='str')

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    2
# dtype: int64

# %%
df.head(47)
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975                      NaN
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991                      NaN
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df['per capita income (US$)'] = df['per capita income (US$)'].fillna(df['per capita income (US$)'].mean())

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
y=df.drop('year',axis='columns')

# %%
x=df[['year']]

# %%
x
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5              19244.048888
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             19244.048888
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975             19244.048888
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             19244.048888
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
reg.predict([[2020]])
# Out:
# C:\Users\Zaid Khan\Desktop\myenv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[40855.86228176]])

# %%
reg.coef_
# Out:
# array([[800.43753312]])

# %%
reg.intercept_
# Out:
# array([-1576027.95461115])

# %%
c=(800.43753312*2020)+-1576027.95461115

# %%
c
# Out:
# 40855.86229124991

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
new_df=pd.read_csv('years.csv')

# %%
predict=reg.predict(new_df)

# %%
predict
# Out:
# array([[-1.83765152e+04],
#        [-1.75760776e+04],
#        [-1.67756401e+04],
#        [-1.59752026e+04],
#        [-1.51747650e+04],
#        [-1.43743275e+04],
#        [-1.35738900e+04],
#        [-1.27734524e+04],
#        [-1.19730149e+04],
#        [-1.11725774e+04],
#        [-1.03721398e+04],
#        [-9.57170230e+03],
#        [-8.77126477e+03],
#        [-7.97082724e+03],
#        [-7.17038971e+03],
#        [-6.36995217e+03],
#        [-5.56951464e+03],
#        [-4.76907711e+03],
#        [-3.96863957e+03],
#        [-3.16820204e+03],
#        [-2.36776451e+03],
#        [-1.56732697e+03],
#        [-7.66889440e+02],
#        [ 3.35480929e+01],
#        [ 8.33985626e+02],
#        [ 1.63442316e+03],
#        [ 2.43486069e+03],
#        [ 3.23529823e+03],
#        [ 4.03573576e+03],
#        [ 4.83617329e+03],
#        [ 5.63661082e+03],
#        [ 6.43704836e+03],
#        [ 7.23748589e+03],
#        [ 8.03792342e+03],
#        [ 8.83836096e+03],
# ...

# %%
new_df['Prediction']=predict

# %%
new_df.head(50)
# Out:
#     year    Prediction
# 0   1946 -18376.515169
# 1   1947 -17576.077636
# 2   1948 -16775.640103
# 3   1949 -15975.202569
# 4   1950 -15174.765036
# 5   1951 -14374.327503
# 6   1952 -13573.889970
# 7   1953 -12773.452437
# 8   1954 -11973.014904
# 9   1955 -11172.577371
# 10  1956 -10372.139838
# 11  1957  -9571.702305
# 12  1958  -8771.264771
# 13  1959  -7970.827238
# 14  1960  -7170.389705
# 15  1961  -6369.952172
# 16  1962  -5569.514639
# 17  1963  -4769.077106
# 18  1964  -3968.639573
# 19  1965  -3168.202040
# 20  1966  -2367.764506
# 21  1967  -1567.326973
# 22  1968   -766.889440
# 23  1969     33.548093
# 24  1970    833.985626
# 25  1971   1634.423159
# 26  1972   2434.860692
# 27  1973   3235.298225
# 28  1974   4035.735758
# 29  1975   4836.173292
# 30  1976   5636.610825
# 31  1977   6437.048358
# 32  1978   7237.485891
# 33  1979   8037.923424
# 34  1980   8838.360957
# 35  1981   9638.798490
# 36  1982  10439.236023
# 37  1983  11239.673556
# 38  1984  12040.111090
# ...

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975             19244.048888
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             19244.048888
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
new_df.to_csv("years.csv")

# %%
plt.figure(figsize=(10, 6))
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.scatter(df['year'], df['per capita income (US$)'], color='blue', label='Original Income')
plt.plot(new_df[['year']], reg.predict(new_df[['year']]), color='red', label='Predicted Income')
plt.legend()
plt.show()
